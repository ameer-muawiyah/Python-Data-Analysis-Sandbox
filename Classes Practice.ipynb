# %% [markdown]
# # Analyzing Customer Feedback of a Product

# %% [markdown]
# #Press Shift+Enter to run the code
# class TextAnalyzer(object):
#
#     def __init__ (self, text):
#         # remove punctuation
#         formattedText = re.sub(r"[.!?,]", "", text)
#         # make text lowercase
#         formattedText = formattedText.lower()
#         self.fmtText = formattedText
#
#
#     def freqAll(self):
#         # split text into words
#         separated_words = self.fmtText.split()
#         # Create dictionary
#         freq_dict = {}
#
#         for word in separated_words:
#             if word in freq_dict:
#                 freq_dict[word] += 1
#             else:
#                 freq_dict[word] = 1
#
#         return freq_dict
#
#     def freqOf(self,word):
#         # get frequency map
#         word_map = self.freqAll()
#
#         if word in word_map:
#             return word_map[word]
#         else:
#             return 0

# %%
givenstring = "I absolutely love this new laptop! The screen is beautiful, and the battery life is amazing. However, the keyboard is a bit too loud. I use the keyboard, every single day for work, so a loud keyboard is annoying. Overall, great laptop, but please fix the keyboard."

# %%
analyzed = TextAnalyzer(givenstring)

# %%
print("Formatted Text:", analyzed.fmtText)

# %%
words_freq = analyzed.freqAll()
words_freq

# %%
freq_keyboard = analyzed.freqOf("keyboard")
freq_keyboard
